# %% [markdown]
# # Financial News API
#
# This is a tutorial notebook for accessing text content related to financial stocks. In particular, it acts as a client example to connect to a news search engine instance, hosting the news headline dataset found here:
#  * https://www.kaggle.com/miguelaenlle/massive-stock-news-analysis-db-for-nlpbacktests

# %% [markdown]
# ## Terrier Search Client
#
# For the hackathon, we have hosted a search index backed by the open source Terrier search engine (http://terrier.org) containing the documents in the above dataset. To connect to this search back-end in Python, we need a libruary called PyTerrier. You can find documentation for PyTerrier here:
#  * https://pyterrier.readthedocs.io/en/latest/
#
# If you are running this notebook on the javiersanzcruza/pyterrier-jupyter docker container image, then you are good-to-go, as PyTerrier is already installed. otherwise, run the command below:

# %%
# Install PyTerrier
# !pip install python-terrier

# %% [markdown]
# Next we need to import and initalize PyTerrier, this checks that all the components of the libruary are available and functioning:

# %%
import pyterrier as pt
import requests
pt.init()

# %% [markdown]
# Since we will be using a remote pre-built index, we need to tell PyTerrier where to find the access end-point for that index, we do this with a search index reference, or IndexRef for short. In this case, 'http://superfp7.terrier.org/newspt/' points at where the search index is currently hosted, if using a different index, you would instead point it at a different location.

# %%
indexref = pt.IndexRef.of("http://superfp7.terrier.org/newspt/")

# %% [markdown]
# Now that PyTerrier knows where the index is, we can issue queries to it. You can find out more about retrieval here:
#  * https://pyterrier.readthedocs.io/en/latest/terrier-retrieval.html
#
# However, in short, we first create a 'Retriever' object, which you can think as a delivery service that we are going to send our queries with. This retriever has an target index address which is set by our IndexRef, and can contain some additional instructions to be looked at by the remote index when executing our queries. In this case, we are setting a weighting model (wmodel) that specifies how documents are scored (DPH), and setting the number of top results to return to 20.

# %%
retriever = pt.BatchRetrieve(indexref, wmodel="DPH", num_results = 20)

# %% [markdown]
# Once this is done, we can then use the search method on the Retriever to issue a query, this will return a Pandas Dataframe with \[‘qid’, ‘docno’, ‘rank’, ‘score’\] columns. qid is the id of the query (used if we send multiple queries at once), docno is the id of a retrieved document, rank is the rank of that document in the results, and score is the weighting model score for that document.

# %%
results = retriever.search("ipad")
results
# Out:
#    qid  docid    docno  rank     score query
# 0    1      0  1615315     0  5.734333  ipad
# 1    1      0  1076704     1  5.701370  ipad
# 2    1      0     8415     2  5.656921  ipad
# 3    1      0   991459     3  5.656921  ipad
# 4    1      0  1394454     4  5.656921  ipad
# 5    1      0  1840194     5  5.656921  ipad
# 6    1      0   210249     6  5.597101  ipad
# 7    1      0   947895     7  5.597101  ipad
# 8    1      0  1440495     8  5.597101  ipad
# 9    1      0  1514808     9  5.597101  ipad
# 10   1      0  1756180    10  5.597101  ipad
# 11   1      0    22899    11  5.516264  ipad
# 12   1      0   201580    12  5.516264  ipad
# 13   1      0   201654    13  5.516264  ipad
# 14   1      0   201691    14  5.516264  ipad
# 15   1      0   223619    15  5.516264  ipad
# 16   1      0   278694    16  5.516264  ipad
# 17   1      0   337447    17  5.516264  ipad
# 18   1      0   363327    18  5.516264  ipad
# 19   1      0   370507    19  5.516264  ipad

# %% [markdown]
# ## Getting the News Article Data
#
# As we can see, we get a ranked list of document identifiers back for the specified query, however, in most cases what we want are the contents of the documents, not just the id's of those documents, so we also need to get those. for efficiency reasons, we keep the document contents separate from the search index, so we need to request the content for a document given its id from a separate service.
#
# In particular, we have a key-value store set up that allows requests for the headline for a document with a given id:

# %%
x = requests.get('http://superfp7.terrier.org/newsapi/headline/1615315')
x.text
# Out:
# "Dow 30 Stock Roundup: Apple's New iPad, Japanese Label Expansion for Merck/ Eisai's Lenvima"

# %% [markdown]
# We can simply iterate over the results dataframe, retrieve each headline in turn, and then append the results to the dataframe:

# %%
headlines = []
for index, row in results.iterrows():
    headline = requests.get('http://superfp7.terrier.org/newsapi/headline/'+row['docno']).text
    headlines.append(headline)
    
results.insert(5, "Headline", headlines, True)
results
# Out:
#    qid  docid    docno  rank     score  \
# 0    1      0  1615315     0  5.734333
# 1    1      0  1076704     1  5.701370
# 2    1      0     8415     2  5.656921
# 3    1      0   991459     3  5.656921
# 4    1      0  1394454     4  5.656921
# 5    1      0  1840194     5  5.656921
# 6    1      0   210249     6  5.597101
# 7    1      0   947895     7  5.597101
# 8    1      0  1440495     8  5.597101
# 9    1      0  1514808     9  5.597101
# 10   1      0  1756180    10  5.597101
# 11   1      0    22899    11  5.516264
# 12   1      0   201580    12  5.516264
# 13   1      0   201654    13  5.516264
# 14   1      0   201691    14  5.516264
# 15   1      0   223619    15  5.516264
# 16   1      0   278694    16  5.516264
# 17   1      0   337447    17  5.516264
# 18   1      0   363327    18  5.516264
# 19   1      0   370507    19  5.516264
#
#                                              Headline query
# 0   Dow 30 Stock Roundup: Apple's New iPad, Japane...  ipad
# 1   Amazon (AMZN) Kindle Fire Leaps To No. 2 Behin...  ipad
# 2   Apple Now a Strong Buy, New iPhones & iPad Key...  ipad
# 3   Apple Now a Strong Buy, New iPhones & iPad Key...  ipad
# 4   Apple Now a Strong Buy, New iPhones & iPad Key...  ipad
# 5   ZAGG Unveils Slim Book Wireless Keyboard and C...  ipad
# 6   BMO Launches iPad App with Integrated Access t...  ipad
# 7   Top 7 Stocks Apple iPad May Help, Chips To Tes...  ipad
# 8   3D Systems' New iSense to Enhance iPad Photogr...  ipad
# 9   3D Systems' New iSense to Enhance iPad Photogr...  ipad
# 10  Twitter To Apple TV; Apple's New iPad?; Dropbo...  ipad
# 11  Barclays downgrades ADI, doesn't expect Force ...  ipad
# 12  Suppose Apple's iPad Dominates Tablets Like th...  ipad
# 13  Amazon Kindle Fire Apps, Like Apple iPad Apps,...  ipad
# 14  Targeting Apple's iPad, Amazon.com to Sell Kin...  ipad
# 15  Apple iPad Mini 2 winners include Cirrus Logic...  ipad
# 16  Stocks Gain In Lower Volume; Apple Up 2% On iP...  ipad
# 17  'Mad Money' Recap: Apple Riding High With the ...  ipad
# 18  Apple iPad Mini 2 winners include Cirrus Logic...  ipad
# 19  3M Introduces New iPad Application for Water D...  ipad

# %% [markdown]
# We can similarly ask for other information about the news article from the same end-point:
#  * headline/docno : Given the numerical identifier of a news item, returns its headline.
#  * url/docno: Given the numerical identifier of a news item, returns its URL.
#  * date/docno : Given the numerical identifier of a news item, returns its publication date.
#  * stock/docno : Given the numerical identifier of a news item, returns its ticker.
#  * news/docno : Given the numerical identifier of a news item, returns its information (headline, url, date and ticker) in JSON format.
#
#
# For example, if we wanted the predicted stock ticker added for each document, we could run:

# %%
stocktickers = []
for index, row in results.iterrows():
    ticker = requests.get('http://superfp7.terrier.org/newsapi/stock/'+row['docno']).text
    stocktickers.append(ticker)
    
results.insert(6, "Ticker", stocktickers, True)
results
# Out:
#    qid  docid    docno  rank     score  \
# 0    1      0  1615315     0  5.734333
# 1    1      0  1076704     1  5.701370
# 2    1      0     8415     2  5.656921
# 3    1      0   991459     3  5.656921
# 4    1      0  1394454     4  5.656921
# 5    1      0  1840194     5  5.656921
# 6    1      0   210249     6  5.597101
# 7    1      0   947895     7  5.597101
# 8    1      0  1440495     8  5.597101
# 9    1      0  1514808     9  5.597101
# 10   1      0  1756180    10  5.597101
# 11   1      0    22899    11  5.516264
# 12   1      0   201580    12  5.516264
# 13   1      0   201654    13  5.516264
# 14   1      0   201691    14  5.516264
# 15   1      0   223619    15  5.516264
# 16   1      0   278694    16  5.516264
# 17   1      0   337447    17  5.516264
# 18   1      0   363327    18  5.516264
# 19   1      0   370507    19  5.516264
#
#                                              Headline Ticker query
# 0   Dow 30 Stock Roundup: Apple's New iPad, Japane...    TOT  ipad
# 1   Amazon (AMZN) Kindle Fire Leaps To No. 2 Behin...    MMI  ipad
# 2   Apple Now a Strong Buy, New iPhones & iPad Key...   ABTL  ipad
# 3   Apple Now a Strong Buy, New iPhones & iPad Key...   LIQD  ipad
# 4   Apple Now a Strong Buy, New iPhones & iPad Key...   RMBS  ipad
# 5   ZAGG Unveils Slim Book Wireless Keyboard and C...   ZAGG  ipad
# 6   BMO Launches iPad App with Integrated Access t...    BMO  ipad
# 7   Top 7 Stocks Apple iPad May Help, Chips To Tes...   KLAC  ipad
# 8   3D Systems' New iSense to Enhance iPad Photogr...   SCSC  ipad
# 9   3D Systems' New iSense to Enhance iPad Photogr...   SPLS  ipad
# 10  Twitter To Apple TV; Apple's New iPad?; Dropbo...   WDAY  ipad
# 11  Barclays downgrades ADI, doesn't expect Force ...    ADI  ipad
# 12  Suppose Apple's iPad Dominates Tablets Like th...    BKS  ipad
# 13  Amazon Kindle Fire Apps, Like Apple iPad Apps,...    BKS  ipad
# 14  Targeting Apple's iPad, Amazon.com to Sell Kin...    BKS  ipad
# 15  Apple iPad Mini 2 winners include Cirrus Logic...   BRCM  ipad
# 16  Stocks Gain In Lower Volume; Apple Up 2% On iP...     CF  ipad
# 17  'Mad Money' Recap: Apple Riding High With the ...    COH  ipad
# 18  Apple iPad Mini 2 winners include Cirrus Logic...   CRUS  ipad
# 19  3M Introduces New iPad Application for Water D...    CSL  ipad

# %% [markdown]
# Where possible, we have also collected meta-data for each company ticker:

# %%
import json

tickerdata = json.loads(requests.get('http://superfp7.terrier.org/newsapi/ticker/AAPL').text)
print(json.dumps(tickerdata, indent=4, sort_keys=True))
# Out:
# {
#     "52WeekChange": {
#         "10": null
#     },
#     "SandP52WeekChange": {
#         "10": null
#     },
#     "address1": {
#         "10": "One Apple Park Way"
#     },
#     "address2": {
#         "10": null
#     },
#     "algorithm": {
#         "10": null
#     },
#     "annualHoldingsTurnover": {
#         "10": null
#     },
#     "annualReportExpenseRatio": {
#         "10": null
#     },
#     "ask": {
#         "10": 157.87
#     },
#     "askSize": {
#         "10": 1100.0
#     },
#     "averageDailyVolume10Day": {
#         "10": 74388970.0
#     },
#     "averageDailyVolume3Month": {
#         "10": null
#     },
#     "averageVolume": {
#         "10": 76245489.0
#     },
#     "averageVolume10days": {
#         "10": 74388970.0
#     },
#     "beta": {
#         "10": 1.202797
#     },
#     "beta3Year": {
#         "10": null
#     },
#     "bid": {
#         "10": 157.85
#     },
#     "bidSize": {
#         "10": 1000.0
#     },
#     "bondHoldings": {
#         "10": null
#     },
#     "bondPosition": {
#         "10": null
#     },
#     "bondRatings": {
#         "10": null
#     },
#     "bookValue": {
#         "10": 4.146
#     },
#     "cashPosition": {
#         "10": null
#     },
#     "category": {
#         "10": null
#     },
#     "circulatingSupply": {
#         "10": null
#     },
#     "city": {
#         "10": "Cupertino"
#     },
#     "companyOfficers": {
#         "10": "[]"
#     },
#     "convertiblePosition": {
#         "10": null
#     },
#     "country": {
#         "10": "United States"
#     },
#     "currency": {
#         "10": "USD"
#     },
#     "currencySymbol": {
#         "10": null
#     },
#     "currentPrice": {
#         "10": 157.87
#     },
#     "currentRatio": {
#         "10": 1.062
#     },
#     "dateShortInterest": {
#         "10": 1626307200.0
#     },
#     "dayHigh": {
#         "10": 158.67
#     },
#     "dayLow": {
#         "10": 153.06
#     },
#     "debtToEquity": {
#         "10": 210.782
#     },
#     "dividendRate": {
#         "10": 0.88
#     },
#     "dividendYield": {
#         "10": 0.006
#     },
#     "earningsGrowth": {
#         "10": 1.0
#     },
#     "earningsQuarterlyGrowth": {
#         "10": 0.932
#     },
#     "ebitda": {
#         "10": 110934999040.0
#     },
#     "ebitdaMargins": {
#         "10": 0.31955
#     },
#     "enterpriseToEbitda": {
#         "10": 22.441
#     },
#     "enterpriseToRevenue": {
#         "10": 7.171
#     },
#     "enterpriseValue": {
#         "10": 2489513410560.0
#     },
#     "equityHoldings": {
#         "10": null
#     },
#     "err": {
#         "10": null
#     },
#     "exDividendDate": {
#         "10": 1628208000.0
#     },
#     "exchange": {
#         "10": "NMS"
#     },
#     "exchangeDataDelayedBy": {
#         "10": null
#     },
#     "exchangeName": {
#         "10": null
#     },
#     "exchangeTimezoneName": {
#         "10": "America/New_York"
#     },
#     "exchangeTimezoneShortName": {
#         "10": "EST"
#     },
#     "expireDate": {
#         "10": null
#     },
#     "fax": {
#         "10": null
#     },
#     "fiftyDayAverage": {
#         "10": 147.3724
#     },
#     "fiftyTwoWeekHigh": {
#         "10": 161.02
#     },
#     "fiftyTwoWeekLow": {
#         "10": 112.59
#     },
#     "financialCurrency": {
#         "10": "USD"
#     },
#     "fiveYearAverageReturn": {
#         "10": null
#     },
#     "fiveYearAvgDividendYield": {
#         "10": 1.29
#     },
#     "floatShares": {
#         "10": 16513139929.0
#     },
#     "forwardEps": {
#         "10": 5.35
#     },
#     "forwardPE": {
#         "10": 29.508411
#     },
#     "freeCashflow": {
#         "10": 80625876992.0
#     },
#     "fromCurrency": {
#         "10": null
#     },
#     "fullTimeEmployees": {
#         "10": 147000.0
#     },
#     "fundFamily": {
#         "10": null
#     },
#     "fundInceptionDate": {
#         "10": null
#     },
#     "gmtOffSetMilliseconds": {
#         "10": -18000000.0
#     },
#     "grossMargins": {
#         "10": 0.41005
#     },
#     "grossProfits": {
#         "10": 104956000000.0
#     },
#     "headSymbol": {
#         "10": null
#     },
#     "heldPercentInsiders": {
#         "10": 0.00069
#     },
#     "heldPercentInstitutions": {
#         "10": 0.59054
#     },
#     "holdings": {
#         "10": null
#     },
#     "impliedSharesOutstanding": {
#         "10": null
#     },
#     "industry": {
#         "10": "Consumer Electronics"
#     },
#     "isEsgPopulated": {
#         "10": true
#     },
#     "lastCapGain": {
#         "10": null
#     },
#     "lastDividendDate": {
#         "10": null
#     },
#     "lastDividendValue": {
#         "10": null
#     },
#     "lastFiscalYearEnd": {
#         "10": 1601078400.0
#     },
#     "lastMarket": {
#         "10": null
#     },
#     "lastSplitDate": {
#         "10": 1598832000.0
#     },
#     "lastSplitFactor": {
#         "10": "4:1"
#     },
#     "legalType": {
#         "10": null
#     },
#     "logo_url": {
#         "10": "https://logo.clearbit.com/apple.com"
#     },
#     "longBusinessSummary": {
#         "10": "Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, iPod touch, and other Apple-branded and third-party accessories. It also provides AppleCare support services; cloud services store services; and operates various platforms, including the App Store, that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It sells and delivers third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1977 and is headquartered in Cupertino, California."
#     },
#     "longName": {
#         "10": "Apple Inc."
#     },
#     "market": {
#         "10": "us_market"
#     },
#     "marketCap": {
#         "10": 2634471178240.0
#     },
#     "marketState": {
#         "10": null
#     },
#     "maxAge": {
#         "10": 1.0
#     },
#     "maxSupply": {
#         "10": null
#     },
#     "messageBoardId": {
#         "10": "finmb_24937"
#     },
#     "morningStarOverallRating": {
#         "10": null
#     },
#     "morningStarRiskRating": {
#         "10": null
#     },
#     "mostRecentQuarter": {
#         "10": 1624665600.0
#     },
#     "navPrice": {
#         "10": null
#     },
#     "netIncomeToCommon": {
#         "10": 86801997824.0
#     },
#     "nextFiscalYearEnd": {
#         "10": 1664150400.0
#     },
#     "numberOfAnalystOpinions": {
#         "10": 43.0
#     },
#     "open": {
#         "10": 153.71
#     },
#     "openInterest": {
#         "10": null
#     },
#     "operatingCashflow": {
#         "10": 104414003200.0
#     },
#     "operatingMargins": {
#         "10": 0.28788
#     },
#     "otherPosition": {
#         "10": null
#     },
#     "payoutRatio": {
#         "10": 0.16309999
#     },
#     "pegRatio": {
#         "10": 1.4
#     },
#     "phone": {
#         "10": "408-996-1010"
#     },
#     "postMarketChange": {
#         "10": null
#     },
#     "postMarketPrice": {
#         "10": null
#     },
#     "postMarketSource": {
#         "10": null
#     },
#     "preMarketChange": {
#         "10": null
#     },
#     "preMarketPrice": {
#         "10": null
#     },
#     "preMarketSource": {
#         "10": null
#     },
#     "preferredPosition": {
#         "10": null
#     },
#     "previousClose": {
#         "10": 153.49
#     },
#     "priceHint": {
#         "10": 2.0
#     },
#     "priceToBook": {
#         "10": 38.077663
#     },
#     "priceToSalesTrailing12Months": {
#         "10": 7.588746
#     },
#     "profitMargins": {
#         "10": 0.25004
#     },
#     "quickRatio": {
#         "10": 0.887
#     },
#     "quoteSourceName": {
#         "10": null
#     },
#     "quoteType": {
#         "10": "EQUITY"
#     },
#     "recommendationKey": {
#         "10": "buy"
#     },
#     "recommendationMean": {
#         "10": 1.9
#     },
#     "regularMarketChange": {
#         "10": null
#     },
#     "regularMarketChangePercent": {
#         "10": null
#     },
#     "regularMarketDayHigh": {
#         "10": 158.67
#     },
#     "regularMarketDayLow": {
#         "10": 153.06
#     },
#     "regularMarketOpen": {
#         "10": 153.71
#     },
#     "regularMarketPreviousClose": {
#         "10": 153.49
#     },
#     "regularMarketPrice": {
#         "10": 157.87
#     },
#     "regularMarketSource": {
#         "10": null
#     },
#     "regularMarketTime": {
#         "10": null
#     },
#     "regularMarketVolume": {
#         "10": 137347929.0
#     },
#     "returnOnAssets": {
#         "10": 0.19302
#     },
#     "returnOnEquity": {
#         "10": 1.27125
#     },
#     "revenueGrowth": {
#         "10": 0.364
#     },
#     "revenuePerShare": {
#         "10": 20.61
#     },
#     "revenueQuarterlyGrowth": {
#         "10": null
#     },
#     "sector": {
#         "10": "Technology"
#     },
#     "sectorWeightings": {
#         "10": null
#     },
#     "sharesOutstanding": {
#         "10": 16687599616.0
#     },
#     "sharesPercentSharesOut": {
#         "10": 0.0058
#     },
#     "sharesShort": {
#         "10": 96355309.0
#     },
#     "sharesShortPreviousMonthDate": {
#         "10": 1623715200.0
#     },
#     "sharesShortPriorMonth": {
#         "10": 108937943.0
#     },
#     "shortName": {
#         "10": "Apple Inc."
#     },
#     "shortPercentOfFloat": {
#         "10": 0.0058
#     },
#     "shortRatio": {
#         "10": 1.14
#     },
#     "startDate": {
#         "10": null
#     },
#     "state": {
#         "10": "CA"
#     },
#     "stockPosition": {
#         "10": null
#     },
#     "strikePrice": {
#         "10": null
#     },
#     "symbol": {
#         "10": "AAPL"
#     },
#     "targetHighPrice": {
#         "10": 190.0
#     },
#     "targetLowPrice": {
#         "10": 132.0
#     },
#     "targetMeanPrice": {
#         "10": 167.13
#     },
#     "targetMedianPrice": {
#         "10": 169.28
#     },
#     "threeYearAverageReturn": {
#         "10": null
#     },
#     "ticker": {
#         "10": "AAPL"
#     },
#     "toCurrency": {
#         "10": null
#     },
#     "totalAssets": {
#         "10": null
#     },
#     "totalCash": {
#         "10": 61696000000.0
#     },
#     "totalCashPerShare": {
#         "10": 3.732
#     },
#     "totalDebt": {
#         "10": 135491002368.0
#     },
#     "totalRevenue": {
#         "10": 347155005440.0
#     },
#     "tradeable": {
#         "10": false
#     },
#     "trailingAnnualDividendRate": {
#         "10": 0.82
#     },
#     "trailingAnnualDividendYield": {
#         "10": 0.0053423676
#     },
#     "trailingEps": {
#         "10": 4.449
#     },
#     "trailingPE": {
#         "10": 35.48438
#     },
#     "twoHundredDayAverage": {
#         "10": 137.6976
#     },
#     "underlyingExchangeSymbol": {
#         "10": null
#     },
#     "underlyingSymbol": {
#         "10": null
#     },
#     "uuid": {
#         "10": "8b10e4ae-9eeb-3684-921a-9ab27e4d87aa"
#     },
#     "volume": {
#         "10": 137347929.0
#     },
#     "volume24Hr": {
#         "10": null
#     },
#     "volumeAllCurrencies": {
#         "10": null
#     },
#     "website": {
#         "10": "http://www.apple.com"
#     },
#     "yield": {
#         "10": null
#     },
#     "ytdReturn": {
#         "10": null
#     },
#     "zip": {
#         "10": "95014"
#     }
# }

# %% [markdown]
# We could similarly grab data fro this to attach to our search results:

# %%
tickerdatas = []
for index, row in results.iterrows():
    ticker = requests.get('http://superfp7.terrier.org/newsapi/ticker/'+row['Ticker']).text
    tickerJSON = json.loads(ticker)
    tickerdatas.append(tickerJSON['longName'])
    
results.insert(7, "Company Name", tickerdatas, True)
results
# Out:
#    qid  docid    docno  rank     score  \
# 0    1      0  1615315     0  5.734333
# 1    1      0  1076704     1  5.701370
# 2    1      0     8415     2  5.656921
# 3    1      0   991459     3  5.656921
# 4    1      0  1394454     4  5.656921
# 5    1      0  1840194     5  5.656921
# 6    1      0   210249     6  5.597101
# 7    1      0   947895     7  5.597101
# 8    1      0  1440495     8  5.597101
# 9    1      0  1514808     9  5.597101
# 10   1      0  1756180    10  5.597101
# 11   1      0    22899    11  5.516264
# 12   1      0   201580    12  5.516264
# 13   1      0   201654    13  5.516264
# 14   1      0   201691    14  5.516264
# 15   1      0   223619    15  5.516264
# 16   1      0   278694    16  5.516264
# 17   1      0   337447    17  5.516264
# 18   1      0   363327    18  5.516264
# 19   1      0   370507    19  5.516264
#
#                                              Headline Ticker  \
# 0   Dow 30 Stock Roundup: Apple's New iPad, Japane...    TOT
# 1   Amazon (AMZN) Kindle Fire Leaps To No. 2 Behin...    MMI
# 2   Apple Now a Strong Buy, New iPhones & iPad Key...   ABTL
# 3   Apple Now a Strong Buy, New iPhones & iPad Key...   LIQD
# 4   Apple Now a Strong Buy, New iPhones & iPad Key...   RMBS
# 5   ZAGG Unveils Slim Book Wireless Keyboard and C...   ZAGG
# 6   BMO Launches iPad App with Integrated Access t...    BMO
# 7   Top 7 Stocks Apple iPad May Help, Chips To Tes...   KLAC
# 8   3D Systems' New iSense to Enhance iPad Photogr...   SCSC
# 9   3D Systems' New iSense to Enhance iPad Photogr...   SPLS
# 10  Twitter To Apple TV; Apple's New iPad?; Dropbo...   WDAY
# 11  Barclays downgrades ADI, doesn't expect Force ...    ADI
# 12  Suppose Apple's iPad Dominates Tablets Like th...    BKS
# 13  Amazon Kindle Fire Apps, Like Apple iPad Apps,...    BKS
# 14  Targeting Apple's iPad, Amazon.com to Sell Kin...    BKS
# 15  Apple iPad Mini 2 winners include Cirrus Logic...   BRCM
# 16  Stocks Gain In Lower Volume; Apple Up 2% On iP...     CF
# 17  'Mad Money' Recap: Apple Riding High With the ...    COH
# 18  Apple iPad Mini 2 winners include Cirrus Logic...   CRUS
# 19  3M Introduces New iPad Application for Water D...    CSL
#
#                                   Company Name query
# 0                               {'3641': None}  ipad
# 1         {'2374': 'Marcus & Millichap, Inc.'}  ipad
# 2                                           {}  ipad
# 3                                           {}  ipad
# 4                      {'3176': 'Rambus Inc.'}  ipad
# 5                               {'4050': None}  ipad
# 6                  {'499': 'Bank of Montreal'}  ipad
# 7                  {'2085': 'KLA Corporation'}  ipad
# 8                 {'3280': 'ScanSource, Inc.'}  ipad
# 9                                           {}  ipad
# 10                   {'3931': 'Workday, Inc.'}  ipad
# 11              {'61': 'Analog Devices, Inc.'}  ipad
# 12                               {'477': None}  ipad
# 13                               {'477': None}  ipad
# 14                               {'477': None}  ipad
# 15                                          {}  ipad
# 16     {'697': 'CF Industries Holdings, Inc.'}  ipad
# 17                                          {}  ipad
# 18               {'899': 'Cirrus Logic, Inc.'}  ipad
# 19  {'912': 'Carlisle Companies Incorporated'}  ipad
